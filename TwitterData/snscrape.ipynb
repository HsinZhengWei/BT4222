# %%
import numpy as np
import snscrape.modules.twitter as sntwitter
import pandas as pd
from datetime import date, timedelta
from datetime import datetime as dt

# %%
# Specify the search criteria
keyword = 'aapl'
start_date = date(2019, 1, 1)
end_date = date(2019, 1, 3)

# Create a list of dates between start_date and end_date
delta = timedelta(days=1)
date_range = pd.date_range(start_date, end_date, freq='D').tolist()

# Create an empty list to store the tweets
tweets = []
#limit of tweets per day
limit = 2000

# Loop over each day in the date range and retrieve X tweets per day
#if count == limit or when the loop ends
for i in range(len(date_range)):
    day = date_range[i].strftime('%Y-%m-%d')
    dayNext = (date_range[i] + timedelta(days = 1)).strftime('%Y-%m-%d')
    query = f'{keyword} since:{day} until:{dayNext} lang:en'
    count = 0
    for tweet in sntwitter.TwitterSearchScraper(query).get_items():
        if (count == limit):
            break
        tweets.append([tweet.date, tweet.content, tweet.username, tweet.likeCount])
        count+= 1
    print(f'{day}: {count} total tweets retrieved')

# Convert the list of tweets to a Pandas DataFrame
df = pd.DataFrame(tweets, columns=['Datetime', 'Text', 'Username', 'likeCount'])
# Out:
# C:\Users\hsinz\AppData\Local\Temp\ipykernel_12040\889322887.py:25: DeprecatedFeatureWarning: content is deprecated, use rawContent instead
#   tweets.append([tweet.date, tweet.content, tweet.username, tweet.likeCount])
# C:\Users\hsinz\AppData\Local\Temp\ipykernel_12040\889322887.py:25: DeprecatedFeatureWarning: username is deprecated, use user.username instead
#   tweets.append([tweet.date, tweet.content, tweet.username, tweet.likeCount])
# 2019-01-01: 311 total tweets retrieved
# 2019-01-02: 2000 total tweets retrieved
# 2019-01-03: 2000 total tweets retrieved

# %%
df
# Out:
#                       Datetime  \
# 0    2019-01-01 23:55:28+00:00
# 1    2019-01-01 23:50:06+00:00
# 2    2019-01-01 23:47:43+00:00
# 3    2019-01-01 23:40:28+00:00
# 4    2019-01-01 23:37:55+00:00
# ...                        ...
# 4306 2019-01-03 17:08:19+00:00
# 4307 2019-01-03 17:08:17+00:00
# 4308 2019-01-03 17:08:12+00:00
# 4309 2019-01-03 17:08:05+00:00
# 4310 2019-01-03 17:07:44+00:00
#
#                                                    Text         Username  \
# 0     $AAPL #patent #maintenance event EXP - Patent ...         treabase
# 1     Early to mid January performer : gs ， aapl  co...      qingxia_NXP
# 2     Join @RobinhoodApp and we'll both get a stock ...       wetthamjoe
# 3     $AAPL #patent #maintenance event EXP - Patent ...         treabase
# 4     @MohnishPabrai @rickbroma I bet the shrimp at ...    88888sAccount
# ...                                                 ...              ...
# 4306  @2kaykim Do you still feel same way after $AAP...     smartone2000
# 4307  $AAPL  Strong momentum. As buyers are coming i...      Adambrill89
# 4308  New Headwinds For The Market $SPX Also $AAPL $...      TalkMarkets
# 4309                         @kxviswan123 Aapl today ?)       Sergei1544
# 4310  Tired Of Winning Yet?\n\n#trump #TradeWar Casu...  lloyd_t_spencer
#
#       likeCount
# 0             0
# 1             0
# 2             1
# 3             0
# 4             0
# ...         ...
# 4306          0
# 4307          0
# 4308          0
# 4309          0
# 4310          3
#
# [4311 rows x 4 columns]

# %%
# change the name
fileName = 'twitter2019.csv'
df.to_csv(fileName, index = False)
